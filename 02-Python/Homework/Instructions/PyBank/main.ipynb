# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('Resources/budget_data.csv')

# Initializations
records = []
numMonths = 0
profit_total = 0
maxMonthlyProfitability = None
minMonthlyProfitability = None
previousMonthlyProfit = None
monthlyProfitChange = 0
totalMonthlyProfitChange = 0

# Open the csv file as an object
with open(csvpath, 'r') as csvfile:

    # Read header
    csvreader = csv.reader(csvfile, delimiter=',')
    csv_header = next(csvreader)

    # Read each row of data after the header
    for row in csvreader:
        
        #print(row)
        
        # Count number of months
        numMonths += 1
        
        # Calculate total Profit/Loss
        monthlyProfitLoss = int(row[1])
        profit_total += monthlyProfitLoss
        
        # Calculate monthly profit change
        if previousMonthlyProfit is None:
            # We are on the first row
            previousMonthlyProfit = monthlyProfitLoss
            print("We are on the first row")
            print(f"previousMonthlyProfit = {previousMonthlyProfit}")
        else:
            # We are not on the first row
            print("We are not on the first row")
            print(f"previousMonthlyProfit = {previousMonthlyProfit}")
            monthlyProfitChange = monthlyProfitLoss - previousMonthlyProfit
            previousMonthlyProfit = monthlyProfitLoss
            
        totalMonthlyProfitChange += monthlyProfitChange

# Average P/L
averagePnl = round(profit_total / numMonths, 2)

# Average monthly profit change
averageMonthlyProfitChange = totalMonthlyProfitChange / (numMonths - 1)

# Print results
print(numMonths)
print(profit_total)
print(averageMonthlyProfitChange)
# Out:
# We are on the first row
# previousMonthlyProfit = 867884
# We are not on the first row
# previousMonthlyProfit = 867884
# We are not on the first row
# previousMonthlyProfit = 984655
# We are not on the first row
# previousMonthlyProfit = 322013
# We are not on the first row
# previousMonthlyProfit = -69417
# We are not on the first row
# previousMonthlyProfit = 310503
# We are not on the first row
# previousMonthlyProfit = 522857
# We are not on the first row
# previousMonthlyProfit = 1033096
# We are not on the first row
# previousMonthlyProfit = 604885
# We are not on the first row
# previousMonthlyProfit = -216386
# We are not on the first row
# previousMonthlyProfit = 477532
# We are not on the first row
# previousMonthlyProfit = 893810
# We are not on the first row
# previousMonthlyProfit = -80353
# We are not on the first row
# previousMonthlyProfit = 779806
# We are not on the first row
# previousMonthlyProfit = -335203
# We are not on the first row
# previousMonthlyProfit = 697845
# We are not on the first row
# previousMonthlyProfit = 793163
# We are not on the first row
# previousMonthlyProfit = 485070
# We are not on the first row
# previousMonthlyProfit = 584122
# We are not on the first row
# previousMonthlyProfit = 62729
# We are not on the first row
# previousMonthlyProfit = 668179
# We are not on the first row
# previousMonthlyProfit = 899906
# We are not on the first row
# previousMonthlyProfit = 834719
# We are not on the first row
# previousMonthlyProfit = 132003
# We are not on the first row
# previousMonthlyProfit = 309978
# We are not on the first row
# previousMonthlyProfit = -755566
# We are not on the first row
# previousMonthlyProfit = 1170593
# We are not on the first row
# previousMonthlyProfit = 252788
# We are not on the first row
# previousMonthlyProfit = 1151518
# We are not on the first row
# previousMonthlyProfit = 817256
# We are not on the first row
# previousMonthlyProfit = 570757
# We are not on the first row
# previousMonthlyProfit = 506702
# We are not on the first row
# previousMonthlyProfit = -1022534
# We are not on the first row
# previousMonthlyProfit = 475062
# We are not on the first row
# previousMonthlyProfit = 779976
# We are not on the first row
# previousMonthlyProfit = 144175
# We are not on the first row
# previousMonthlyProfit = 542494
# We are not on the first row
# previousMonthlyProfit = 359333
# We are not on the first row
# previousMonthlyProfit = 321469
# We are not on the first row
# previousMonthlyProfit = 67780
# We are not on the first row
# previousMonthlyProfit = 471435
# We are not on the first row
# previousMonthlyProfit = 565603
# We are not on the first row
# previousMonthlyProfit = 872480
# We are not on the first row
# previousMonthlyProfit = 789480
# We are not on the first row
# previousMonthlyProfit = 999942
# We are not on the first row
# previousMonthlyProfit = -1196225
# We are not on the first row
# previousMonthlyProfit = 268997
# We are not on the first row
# previousMonthlyProfit = -687986
# We are not on the first row
# previousMonthlyProfit = 1150461
# We are not on the first row
# previousMonthlyProfit = 682458
# We are not on the first row
# previousMonthlyProfit = 617856
# We are not on the first row
# previousMonthlyProfit = 824098
# We are not on the first row
# previousMonthlyProfit = 581943
# We are not on the first row
# previousMonthlyProfit = 132864
# We are not on the first row
# previousMonthlyProfit = 448062
# We are not on the first row
# previousMonthlyProfit = 689161
# We are not on the first row
# previousMonthlyProfit = 800701
# We are not on the first row
# previousMonthlyProfit = 1166643
# We are not on the first row
# previousMonthlyProfit = 947333
# We are not on the first row
# previousMonthlyProfit = 578668
# We are not on the first row
# previousMonthlyProfit = 988505
# We are not on the first row
# previousMonthlyProfit = 1139715
# We are not on the first row
# previousMonthlyProfit = 1029471
# We are not on the first row
# previousMonthlyProfit = 687533
# We are not on the first row
# previousMonthlyProfit = -524626
# We are not on the first row
# previousMonthlyProfit = 158620
# We are not on the first row
# previousMonthlyProfit = 87795
# We are not on the first row
# previousMonthlyProfit = 423389
# We are not on the first row
# previousMonthlyProfit = 840723
# We are not on the first row
# previousMonthlyProfit = 568529
# We are not on the first row
# previousMonthlyProfit = 332067
# We are not on the first row
# previousMonthlyProfit = 989499
# We are not on the first row
# previousMonthlyProfit = 778237
# We are not on the first row
# previousMonthlyProfit = 650000
# We are not on the first row
# previousMonthlyProfit = -1100387
# We are not on the first row
# previousMonthlyProfit = -174946
# We are not on the first row
# previousMonthlyProfit = 757143
# We are not on the first row
# previousMonthlyProfit = 445709
# We are not on the first row
# previousMonthlyProfit = 712961
# We are not on the first row
# previousMonthlyProfit = -1163797
# We are not on the first row
# previousMonthlyProfit = 569899
# We are not on the first row
# previousMonthlyProfit = 768450
# We are not on the first row
# previousMonthlyProfit = 102685
# We are not on the first row
# previousMonthlyProfit = 795914
# We are not on the first row
# previousMonthlyProfit = 60988
# We are not on the first row
# previousMonthlyProfit = 138230
# 86
# 38382578
# -2315.1176470588234
