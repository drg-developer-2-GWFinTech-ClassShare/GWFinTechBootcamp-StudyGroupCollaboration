# %%
# -*- coding: utf-8 -*-
"""Student Do: Sales Analysis.

This script will use the Pathlib library to set the file path,
use the csv library to read in the file, and iterate over each
row of the file to calculate customer sales averages.
"""

# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('../../Resources/sales.csv')

# Initialize list of records
records = []

# Open the csv file as an object
with open(csvpath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    # Print the header
    print(csv_header)
    
    # Append the column 'Average' to the header
    csv_header.append("Average")
    
    # Append the header to the list of records
    records.append(csv_header)
    print(csv_header)
    print(records)
    
    print()
    print(records[0])
    print(records[0][1])
    
    # Read each row of data after the header
    for row in csvreader:
        
        # Print the row
        #print(row)

        # Set the 'name', 'count', and 'revenue' variables for better
        # readability, convert strings to ints for numerical calculations
        name = row[0]
        count = int(row[1])
        revenue = int(row[2])

        #print(name)
        #print(count)
        #print(revenue)

        # Calculate the average and round to the nearest 2 decimal places
        average = round(revenue / count, 2)
        #print(average)
        
        # Append the average to the row
        row.append(average)
        #print(row)
        
        # Append the row to the list of records
        records.append(row)
        print(records)

# Set the path for the output.csv
output = Path("output.csv")

# Open the output path as a file and pass into the 'csv.writer()' function
# Set the delimiter/separater as a ','
with open(output, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Loop through the list of records and write every record to the
    # output csv file
    for record in records:
        csvwriter.writerow(record)
# Out:
# ['Name', 'Count', 'Revenue']
# ['Name', 'Count', 'Revenue', 'Average']
# [['Name', 'Count', 'Revenue', 'Average']]
#
# ['Name', 'Count', 'Revenue', 'Average']
# Count
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8], ['Carl', '1', '300', 300.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8], ['Carl', '1', '300', 300.0], ['Tim', '1', '345', 345.0]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8], ['Carl', '1', '300', 300.0], ['Tim', '1', '345', 345.0], ['Madison', '4', '202', 50.5]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8], ['Carl', '1', '300', 300.0], ['Tim', '1', '345', 345.0], ['Madison', '4', '202', 50.5], ['John', '4', '305', 76.25]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8], ['Carl', '1', '300', 300.0], ['Tim', '1', '345', 345.0], ['Madison', '4', '202', 50.5], ['John', '4', '305', 76.25], ['Phil', '6', '249', 41.5]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8], ['Carl', '1', '300', 300.0], ['Tim', '1', '345', 345.0], ['Madison', '4', '202', 50.5], ['John', '4', '305', 76.25], ['Phil', '6', '249', 41.5], ['Madison', '7', '113', 16.14]]
# [['Name', 'Count', 'Revenue', 'Average'], ['Andrew', '9', '58', 6.44], ['Phil', '8', '377', 47.12], ['Madison', '5', '302', 60.4], ['Sally', '1', '75', 75.0], ['Tyler', '1', '334', 334.0], ['Billy', '7', '146', 20.86], ['Steve', '1', '178', 178.0], ['Madison', '7', '313', 44.71], ['Sarah', '8', '103', 12.88], ['Tim', '5', '344', 68.8], ['Andrew', '5', '349', 69.8], ['Phil', '8', '61', 7.62], ['Madison', '4', '196', 49.0], ['Carl', '1', '374', 374.0], ['Devon', '9', '220', 24.44], ['Megan', '9', '321', 35.67], ['Sarah', '7', '277', 39.57], ['David', '2', '246', 123.0], ['Sally', '9', '198', 22.0], ['Tom', '5', '221', 44.2], ['Andrew', '1', '191', 191.0], ['Paul', '5', '399', 79.8], ['Carl', '1', '300', 300.0], ['Tim', '1', '345', 345.0], ['Madison', '4', '202', 50.5], ['John', '4', '305', 76.25], ['Phil', '6', '249', 41.5], ['Madison', '7', '113', 16.14], ['Sally', '6', '256', 42.67]]
